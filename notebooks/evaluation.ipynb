# %%
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

import json
import numpy as np
from src.pipeline import (
    run_ingestion, build_retriever,
    run_evaluation, QA_PATH
)

# %% [markdown]
# ## 1 · Configuration

# %%
TOP_K = 4
CHUNK_MODES     = ['structural', 'semantic']
RETRIEVAL_MODES = ['bm25', 'dense', 'rrf']
with open(QA_PATH, 'r', encoding='utf-8') as f:
    qa_pairs = json.load(f)
print(f'{len(qa_pairs)} QA pairs loaded')
# Out:
# 20 QA pairs loaded

# %% [markdown]
# ### extracts PDF text, chunks, embeds, and stores everything in SQLite + FAISS

# %%
for mode in CHUNK_MODES:
    run_ingestion(chunk_mode=mode)
# Out:
# ============================================================
#   INGESTION  –  chunk_mode = structural
# ============================================================
#
# [1/4] extracting PDF text …
#   extracting: cricket-rules.pdf
#     -> 44 pages
#   total docs: 1
# [2/4] setting up database …
# [3/4] chunking (structural) …
#    chunks created: 594
# [4/4] embedding chunks …
#    done – 594 chunks stored
#
#
# ============================================================
#   INGESTION  –  chunk_mode = semantic
# ============================================================
#
# [1/4] extracting PDF text …
#   extracting: cricket-rules.pdf
#     -> 44 pages
#   total docs: 1
# [2/4] setting up database …
# [3/4] chunking (semantic) …
#    chunks created: 120
# [4/4] embedding chunks …
#    done – 120 chunks stored

# %%
retrievers = {}
for mode in CHUNK_MODES:
    print(f'retriever for: {mode}')
    retrievers[mode] = build_retriever(chunk_mode=mode)

print('all retrievers ready')
# Out:
# retriever for: structural
#   BM25 index built – 594 chunks
#   FAISS index built – 594 vectors, dim=1536
# retriever for: semantic
#   BM25 index built – 120 chunks
#   FAISS index built – 120 vectors, dim=1536
# all retrievers ready

# %% [markdown]
# ### ablation experiments
#
# | Exp | Chunking    | Retrieval
# |-----|-------------|-----------
# | A1  | structural  |bm25
# | A2  | structural  | dense
# | A3  | structural  |rrf
# | B1  | semantic    | bm25
# | B2  | semantic    | dense
# | B3  | semantic    | rrf

# %%
all_summaries = []
all_details = {}

for cm in CHUNK_MODES:
    for rm in RETRIEVAL_MODES:
        label = f'{cm}+{rm}'
        print(f'EXPERIMENT: {label}')
        summary, details = run_evaluation(
            qa_path=QA_PATH,
            retriever=retrievers[cm],
            chunk_mode=cm,
            retrieval_method=rm,
            top_k=TOP_K,
        )
        summary['label'] = label
        all_summaries.append(summary)
        all_details[label] = details

print('experiments done')
# Out:
# EXPERIMENT: structural+bm25
#   Q1/20: What is the purpose of the ICC Code of Conduct?…
#     EM=0  F1=0.265  grounding=100%  time=2.01s
#   Q2/20: What does Article 2.3 of the Code of Conduct cover?…
#     EM=0  F1=0.051  grounding=0%  time=0.84s
#   Q3/20: What are the offence levels defined in the Code of Cond…
#     EM=0  F1=0.712  grounding=100%  time=1.73s
#   Q4/20: What does Article 2.5 prohibit regarding a dismissed ba…
#     EM=0  F1=0.474  grounding=100%  time=2.42s
#   Q5/20: What is the sanction for changing the condition of the …
#     EM=0  F1=0.143  grounding=0%  time=0.80s
#   Q6/20: Who can report an alleged offence under the Code of Con…
#     EM=0  F1=0.250  grounding=100%  time=1.62s
#   Q7/20: What does Article 2.12 cover regarding physical contact…
#     EM=0  F1=0.311  grounding=100%  time=1.81s
#   Q8/20: Are social media posts considered public under the Code…
#     EM=0  F1=0.600  grounding=100%  time=2.15s
#   Q9/20: What is the reporting deadline for Level 1 and 2 on-fie…
#     EM=0  F1=0.053  grounding=0%  time=0.90s
#   Q10/20: What language must hearings before the Match Referee be…
#     EM=0  F1=0.643  grounding=100%  time=1.48s
#   Q11/20: What does Article 2.9 cover regarding throwing objects?…
#     EM=0  F1=0.040  grounding=0%  time=0.65s
#   Q12/20: What does Article 2.17 say about threats of assault?…
#     EM=0  F1=0.500  grounding=100%  time=2.01s
#   Q13/20: What is the definition of the Spirit of Cricket accordi…
#     EM=0  F1=0.549  grounding=100%  time=2.63s
#   Q14/20: What options does a Player have after receiving a Notic…
#     EM=0  F1=0.048  grounding=0%  time=0.61s
#   Q15/20: How long does the Match Referee have to issue a written…
#     EM=0  F1=0.556  grounding=100%  time=1.36s
#   Q16/20: What types of unfair play does Article 2.10 cover?…
#     EM=0  F1=0.460  grounding=100%  time=2.64s
#   Q17/20: Where is the ICC headquartered according to the Code of…
#     EM=0  F1=0.190  grounding=0%  time=0.87s
#   Q18/20: When did this Code of Conduct become effective?…
#     EM=0  F1=0.857  grounding=100%  time=0.99s
#   Q19/20: What is Article 2.21 about?…
#     EM=0  F1=0.403  grounding=100%  time=3.68s
#   Q20/20: Who is held responsible for offences under Article 2.11…
#     EM=0  F1=0.933  grounding=100%  time=1.34s
#
#   --- structural + bm25 ---
#   EM:        0.000
#   F1:        0.402
#   Grounding: 70.0%
#   p95 lat:   2.69s
# EXPERIMENT: structural+dense
#   Q1/20: What is the purpose of the ICC Code of Conduct?…
#     EM=0  F1=0.707  grounding=100%  time=1.67s
#   Q2/20: What does Article 2.3 of the Code of Conduct cover?…
#     EM=0  F1=0.051  grounding=0%  time=0.85s
#   Q3/20: What are the offence levels defined in the Code of Cond…
#     EM=0  F1=0.417  grounding=100%  time=1.21s
#   Q4/20: What does Article 2.5 prohibit regarding a dismissed ba…
#     EM=0  F1=0.474  grounding=100%  time=2.38s
#   Q5/20: What is the sanction for changing the condition of the …
#     EM=0  F1=0.143  grounding=0%  time=1.01s
#   Q6/20: Who can report an alleged offence under the Code of Con…
#     EM=0  F1=0.245  grounding=0%  time=1.42s
#   Q7/20: What does Article 2.12 cover regarding physical contact…
#     EM=0  F1=0.000  grounding=0%  time=0.90s
#   Q8/20: Are social media posts considered public under the Code…
#     EM=0  F1=0.600  grounding=100%  time=1.67s
#   Q9/20: What is the reporting deadline for Level 1 and 2 on-fie…
#     EM=0  F1=0.585  grounding=100%  time=1.95s
#   Q10/20: What language must hearings before the Match Referee be…
#     EM=0  F1=0.452  grounding=100%  time=1.63s
#   Q11/20: What does Article 2.9 cover regarding throwing objects?…
#     EM=0  F1=0.040  grounding=0%  time=1.10s
#   Q12/20: What does Article 2.17 say about threats of assault?…
#     EM=0  F1=0.492  grounding=100%  time=2.67s
#   Q13/20: What is the definition of the Spirit of Cricket accordi…
#     EM=0  F1=0.439  grounding=100%  time=2.28s
#   Q14/20: What options does a Player have after receiving a Notic…
#     EM=0  F1=0.419  grounding=100%  time=2.52s
#   Q15/20: How long does the Match Referee have to issue a written…
#     EM=0  F1=0.410  grounding=100%  time=2.06s
#   Q16/20: What types of unfair play does Article 2.10 cover?…
#     EM=0  F1=0.043  grounding=0%  time=1.00s
#   Q17/20: Where is the ICC headquartered according to the Code of…
#     EM=0  F1=0.190  grounding=0%  time=0.93s
#   Q18/20: When did this Code of Conduct become effective?…
#     EM=0  F1=0.857  grounding=100%  time=1.25s
#   Q19/20: What is Article 2.21 about?…
#     EM=0  F1=0.057  grounding=0%  time=1.04s
#   Q20/20: Who is held responsible for offences under Article 2.11…
#     EM=0  F1=0.316  grounding=100%  time=1.64s
#
#   --- structural + dense ---
#   EM:        0.000
#   F1:        0.347
#   Grounding: 60.0%
#   p95 lat:   2.53s
# EXPERIMENT: structural+rrf
#   Q1/20: What is the purpose of the ICC Code of Conduct?…
#     EM=0  F1=0.682  grounding=100%  time=2.02s
#   Q2/20: What does Article 2.3 of the Code of Conduct cover?…
#     EM=0  F1=0.051  grounding=0%  time=0.83s
#   Q3/20: What are the offence levels defined in the Code of Cond…
#     EM=0  F1=0.712  grounding=100%  time=1.51s
#   Q4/20: What does Article 2.5 prohibit regarding a dismissed ba…
#     EM=0  F1=0.468  grounding=100%  time=2.29s
#   Q5/20: What is the sanction for changing the condition of the …
#     EM=0  F1=0.143  grounding=0%  time=1.14s
#   Q6/20: Who can report an alleged offence under the Code of Con…
#     EM=0  F1=0.250  grounding=100%  time=1.62s
#   Q7/20: What does Article 2.12 cover regarding physical contact…
#     EM=0  F1=0.000  grounding=0%  time=1.10s
#   Q8/20: Are social media posts considered public under the Code…
#     EM=0  F1=0.447  grounding=100%  time=2.30s
#   Q9/20: What is the reporting deadline for Level 1 and 2 on-fie…
#     EM=0  F1=0.800  grounding=100%  time=1.51s
#   Q10/20: What language must hearings before the Match Referee be…
#     EM=0  F1=0.596  grounding=100%  time=1.72s
#   Q11/20: What does Article 2.9 cover regarding throwing objects?…
#     EM=0  F1=0.040  grounding=0%  time=0.93s
#   Q12/20: What does Article 2.17 say about threats of assault?…
#     EM=0  F1=0.446  grounding=100%  time=2.67s
#   Q13/20: What is the definition of the Spirit of Cricket accordi…
#     EM=0  F1=0.590  grounding=100%  time=2.69s
#   Q14/20: What options does a Player have after receiving a Notic…
#     EM=0  F1=0.151  grounding=100%  time=1.35s
#   Q15/20: How long does the Match Referee have to issue a written…
#     EM=0  F1=0.556  grounding=100%  time=1.63s
#   Q16/20: What types of unfair play does Article 2.10 cover?…
#     EM=0  F1=0.515  grounding=100%  time=1.93s
#   Q17/20: Where is the ICC headquartered according to the Code of…
#     EM=0  F1=0.190  grounding=0%  time=1.12s
#   Q18/20: When did this Code of Conduct become effective?…
#     EM=0  F1=0.857  grounding=100%  time=1.13s
#   Q19/20: What is Article 2.21 about?…
#     EM=0  F1=0.456  grounding=100%  time=3.67s
#   Q20/20: Who is held responsible for offences under Article 2.11…
#     EM=0  F1=0.889  grounding=100%  time=1.42s
#
#   --- structural + rrf ---
#   EM:        0.000
#   F1:        0.442
#   Grounding: 75.0%
#   p95 lat:   2.74s
# EXPERIMENT: semantic+bm25
#   Q1/20: What is the purpose of the ICC Code of Conduct?…
#     EM=0  F1=0.563  grounding=100%  time=1.53s
#   Q2/20: What does Article 2.3 of the Code of Conduct cover?…
#     EM=0  F1=0.051  grounding=0%  time=0.69s
#   Q3/20: What are the offence levels defined in the Code of Cond…
#     EM=0  F1=0.862  grounding=100%  time=1.47s
#   Q4/20: What does Article 2.5 prohibit regarding a dismissed ba…
#     EM=0  F1=0.529  grounding=100%  time=2.35s
#   Q5/20: What is the sanction for changing the condition of the …
#     EM=0  F1=0.143  grounding=0%  time=0.64s
#   Q6/20: Who can report an alleged offence under the Code of Con…
#     EM=0  F1=0.416  grounding=100%  time=3.18s
#   Q7/20: What does Article 2.12 cover regarding physical contact…
#     EM=0  F1=0.481  grounding=100%  time=2.45s
#   Q8/20: Are social media posts considered public under the Code…
#     EM=0  F1=0.414  grounding=100%  time=1.87s
#   Q9/20: What is the reporting deadline for Level 1 and 2 on-fie…
#     EM=0  F1=0.524  grounding=0%  time=2.30s
#   Q10/20: What language must hearings before the Match Referee be…
#     EM=0  F1=0.632  grounding=100%  time=1.38s
#   Q11/20: What does Article 2.9 cover regarding throwing objects?…
#     EM=0  F1=0.475  grounding=100%  time=3.20s
#   Q12/20: What does Article 2.17 say about threats of assault?…
#     EM=0  F1=0.603  grounding=100%  time=2.52s
#   Q13/20: What is the definition of the Spirit of Cricket accordi…
#     EM=0  F1=0.632  grounding=100%  time=2.83s
#   Q14/20: What options does a Player have after receiving a Notic…
#     EM=0  F1=0.467  grounding=100%  time=2.69s
#   Q15/20: How long does the Match Referee have to issue a written…
#     EM=0  F1=0.536  grounding=100%  time=1.61s
#   Q16/20: What types of unfair play does Article 2.10 cover?…
#     EM=0  F1=0.460  grounding=100%  time=7.20s
#   Q17/20: Where is the ICC headquartered according to the Code of…
#     EM=0  F1=0.190  grounding=0%  time=0.63s
#   Q18/20: When did this Code of Conduct become effective?…
#     EM=0  F1=0.857  grounding=100%  time=0.94s
#   Q19/20: What is Article 2.21 about?…
#     EM=0  F1=0.531  grounding=100%  time=2.39s
#   Q20/20: Who is held responsible for offences under Article 2.11…
#     EM=0  F1=0.885  grounding=100%  time=2.12s
#
#   --- semantic + bm25 ---
#   EM:        0.000
#   F1:        0.513
#   Grounding: 80.0%
#   p95 lat:   3.40s
# EXPERIMENT: semantic+dense
#   Q1/20: What is the purpose of the ICC Code of Conduct?…
#     EM=0  F1=0.580  grounding=100%  time=2.43s
#   Q2/20: What does Article 2.3 of the Code of Conduct cover?…
#     EM=0  F1=0.051  grounding=0%  time=0.98s
#   Q3/20: What are the offence levels defined in the Code of Cond…
#     EM=0  F1=0.453  grounding=100%  time=3.36s
#   Q4/20: What does Article 2.5 prohibit regarding a dismissed ba…
#     EM=0  F1=0.474  grounding=100%  time=2.42s
#   Q5/20: What is the sanction for changing the condition of the …
#     EM=0  F1=0.143  grounding=0%  time=1.43s
#   Q6/20: Who can report an alleged offence under the Code of Con…
#     EM=0  F1=0.416  grounding=100%  time=3.19s
#   Q7/20: What does Article 2.12 cover regarding physical contact…
#     EM=0  F1=0.484  grounding=100%  time=2.88s
#   Q8/20: Are social media posts considered public under the Code…
#     EM=0  F1=0.532  grounding=100%  time=2.10s
#   Q9/20: What is the reporting deadline for Level 1 and 2 on-fie…
#     EM=0  F1=0.800  grounding=100%  time=1.91s
#   Q10/20: What language must hearings before the Match Referee be…
#     EM=0  F1=0.632  grounding=100%  time=1.37s
#   Q11/20: What does Article 2.9 cover regarding throwing objects?…
#     EM=0  F1=0.469  grounding=100%  time=3.68s
#   Q12/20: What does Article 2.17 say about threats of assault?…
#     EM=0  F1=0.589  grounding=100%  time=2.66s
#   Q13/20: What is the definition of the Spirit of Cricket accordi…
#     EM=0  F1=0.537  grounding=100%  time=4.06s
#   Q14/20: What options does a Player have after receiving a Notic…
#     EM=0  F1=0.458  grounding=100%  time=2.66s
#   Q15/20: How long does the Match Referee have to issue a written…
#     EM=0  F1=0.536  grounding=100%  time=1.48s
#   Q16/20: What types of unfair play does Article 2.10 cover?…
#     EM=0  F1=0.460  grounding=100%  time=6.39s
#   Q17/20: Where is the ICC headquartered according to the Code of…
#     EM=0  F1=0.190  grounding=0%  time=1.11s
#   Q18/20: When did this Code of Conduct become effective?…
#     EM=0  F1=0.857  grounding=100%  time=1.25s
#   Q19/20: What is Article 2.21 about?…
#     EM=0  F1=0.057  grounding=0%  time=0.83s
#   Q20/20: Who is held responsible for offences under Article 2.11…
#     EM=0  F1=0.351  grounding=100%  time=1.38s
#
#   --- semantic + dense ---
#   EM:        0.000
#   F1:        0.453
#   Grounding: 80.0%
#   p95 lat:   4.18s
# EXPERIMENT: semantic+rrf
#   Q1/20: What is the purpose of the ICC Code of Conduct?…
#     EM=0  F1=0.699  grounding=100%  time=2.04s
#   Q2/20: What does Article 2.3 of the Code of Conduct cover?…
#     EM=0  F1=0.051  grounding=0%  time=0.88s
#   Q3/20: What are the offence levels defined in the Code of Cond…
#     EM=0  F1=0.581  grounding=100%  time=2.93s
#   Q4/20: What does Article 2.5 prohibit regarding a dismissed ba…
#     EM=0  F1=0.545  grounding=100%  time=2.22s
#   Q5/20: What is the sanction for changing the condition of the …
#     EM=0  F1=0.143  grounding=0%  time=0.90s
#   Q6/20: Who can report an alleged offence under the Code of Con…
#     EM=0  F1=0.394  grounding=100%  time=2.83s
#   Q7/20: What does Article 2.12 cover regarding physical contact…
#     EM=0  F1=0.484  grounding=100%  time=3.05s
#   Q8/20: Are social media posts considered public under the Code…
#     EM=0  F1=0.800  grounding=100%  time=1.41s
#   Q9/20: What is the reporting deadline for Level 1 and 2 on-fie…
#     EM=0  F1=0.524  grounding=100%  time=2.42s
#   Q10/20: What language must hearings before the Match Referee be…
#     EM=0  F1=0.744  grounding=100%  time=1.33s
#   Q11/20: What does Article 2.9 cover regarding throwing objects?…
#     EM=0  F1=0.469  grounding=100%  time=4.56s
#   Q12/20: What does Article 2.17 say about threats of assault?…
#     EM=0  F1=0.562  grounding=100%  time=3.17s
#   Q13/20: What is the definition of the Spirit of Cricket accordi…
#     EM=0  F1=0.537  grounding=100%  time=4.40s
#   Q14/20: What options does a Player have after receiving a Notic…
#     EM=0  F1=0.463  grounding=100%  time=3.05s
#   Q15/20: How long does the Match Referee have to issue a written…
#     EM=0  F1=0.718  grounding=100%  time=1.28s
#   Q16/20: What types of unfair play does Article 2.10 cover?…
#     EM=0  F1=0.460  grounding=100%  time=7.04s
#   Q17/20: Where is the ICC headquartered according to the Code of…
#     EM=0  F1=0.190  grounding=0%  time=1.06s
#   Q18/20: When did this Code of Conduct become effective?…
#     EM=0  F1=0.857  grounding=100%  time=1.09s
#   Q19/20: What is Article 2.21 about?…
#     EM=0  F1=0.444  grounding=100%  time=3.17s
#   Q20/20: Who is held responsible for offences under Article 2.11…
#     EM=0  F1=0.889  grounding=0%  time=2.31s
#
#   --- semantic + rrf ---
#   EM:        0.000
#   F1:        0.528
#   Grounding: 80.0%
#   p95 lat:   4.68s
# experiments done

# %% [markdown]
# ## 5 · Results comparison table

# %%
header = f'{"Experiment":<25} {"EM":>6} {"F1":>6} {"Ground%":>8} {"p95(s)":>7}'
print(header)
print('-' * len(header))

for s in all_summaries:
    print(f'{s["label"]:<25} {s["avg_em"]:>6.3f} {s["avg_f1"]:>6.3f} '
          f'{s["avg_grounding"]:>7.1f}% {s["p95_latency"]:>7.2f}')
# Out:
# Experiment                    EM     F1  Ground%  p95(s)
# --------------------------------------------------------
# structural+bm25            0.000  0.402    70.0%    2.69
# structural+dense           0.000  0.347    60.0%    2.53
# structural+rrf             0.000  0.442    75.0%    2.74
# semantic+bm25              0.000  0.513    80.0%    3.40
# semantic+dense             0.000  0.453    80.0%    4.18
# semantic+rrf               0.000  0.528    80.0%    4.68

# %%
def get_summary(label):
    for s in all_summaries:
        if s['label'] == label:
            return s
    return None

print('Chunking ablation  (RRF held constant)')
for lbl in ['structural+rrf', 'semantic+rrf']:
    s = get_summary(lbl)
    if s:
        print(f'  {lbl:<25}  F1={s["avg_f1"]:.3f}  Grounding={s["avg_grounding"]:.1f}%')

print()
print('Retrieval ablation  (structural chunks held constant)')
for lbl in ['structural+bm25', 'structural+dense', 'structural+rrf']:
    s = get_summary(lbl)
    if s:
        print(f'  {lbl:<25}  F1={s["avg_f1"]:.3f}  Grounding={s["avg_grounding"]:.1f}%')

print()
print('Fusion value')
a1, a2, a3 = get_summary('structural+bm25'), get_summary('structural+dense'), get_summary('structural+rrf')
if a1 and a2 and a3:
    best_single = max(a1['avg_f1'], a2['avg_f1'])
    print(f'  best single retriever F1 = {best_single:.3f}')
    print(f'  RRF fusion F1            = {a3["avg_f1"]:.3f}')
    print(f'  delta                    = {a3["avg_f1"] - best_single:+.3f}')
# Out:
# Chunking ablation  (RRF held constant)
#   structural+rrf             F1=0.442  Grounding=75.0%
#   semantic+rrf               F1=0.528  Grounding=80.0%
#
# Retrieval ablation  (structural chunks held constant)
#   structural+bm25            F1=0.402  Grounding=70.0%
#   structural+dense           F1=0.347  Grounding=60.0%
#   structural+rrf             F1=0.442  Grounding=75.0%
#
# Fusion value
#   best single retriever F1 = 0.402
#   RRF fusion F1            = 0.442
#   delta                    = +0.040

# %% [markdown]
# ### Latency
#
# Measure p50, p95, p99 latency
#
# **Acceptance target:** p95 ≤ 2.5 s at top-k=4 for approx 512-token answers.

# %%
print(f'{"Experiment":<25} {"p50(s)":>7} {"p95(s)":>7} {"p99(s)":>7} {"mean(s)":>7}')
for label, details in all_details.items():
    lats = [d['latency'] for d in details]
    p50 = np.percentile(lats, 50)
    p95 = np.percentile(lats, 95)
    p99 = np.percentile(lats, 99)
    mean = np.mean(lats)
    print(f'{label:<25} {p50:>7.2f} {p95:>7.2f} {p99:>7.2f} {mean:>7.2f}')
# Out:
# Experiment                 p50(s)  p95(s)  p99(s) mean(s)
# structural+bm25              1.55    2.69    3.48    1.63
# structural+dense             1.52    2.53    2.64    1.56
# structural+rrf               1.57    2.74    3.48    1.73
# semantic+bm25                2.21    3.40    6.44    2.20
# semantic+dense               2.26    4.18    5.94    2.38
# semantic+rrf                 2.37    4.68    6.57    2.56
