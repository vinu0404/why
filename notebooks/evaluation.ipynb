# %%
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

import json
import numpy as np
from src.pipeline import (
    run_ingestion, build_retriever,
    run_evaluation, QA_PATH
)

# %% [markdown]
# ## 1 · Configuration

# %%
TOP_K = 4
CHUNK_MODES     = ['structural', 'semantic']
RETRIEVAL_MODES = ['bm25', 'dense', 'rrf']
with open(QA_PATH, 'r', encoding='utf-8') as f:
    qa_pairs = json.load(f)
print(f'{len(qa_pairs)} QA pairs loaded')
# Out:
# 20 QA pairs loaded

# %% [markdown]
# ### extracts PDF text, chunks, embeds, and stores everything in SQLite + FAISS

# %%
for mode in CHUNK_MODES:
    run_ingestion(chunk_mode=mode)
# Out:
# ============================================================
#   INGESTION  –  chunk_mode = structural
# ============================================================
#
# [1/4] extracting PDF text …
#   extracting: cricket-rules.pdf
#     -> 44 pages
#   total docs: 1
# [2/4] setting up database …
# [3/4] chunking (structural) …
#    chunks created: 594
# [4/4] embedding chunks …
#    done – 594 chunks stored
#
#
# ============================================================
#   INGESTION  –  chunk_mode = semantic
# ============================================================
#
# [1/4] extracting PDF text …
#   extracting: cricket-rules.pdf
#     -> 44 pages
#   total docs: 1
# [2/4] setting up database …
# [3/4] chunking (semantic) …
#    chunks created: 120
# [4/4] embedding chunks …
#    done – 120 chunks stored

# %%
retrievers = {}
for mode in CHUNK_MODES:
    print(f'retriever for: {mode}')
    retrievers[mode] = build_retriever(chunk_mode=mode)

print('all retrievers ready')
# Out:
# retriever for: structural
#   BM25 index built – 594 chunks
#   FAISS index built – 594 vectors, dim=1536
# retriever for: semantic
#   BM25 index built – 120 chunks
#   FAISS index built – 120 vectors, dim=1536
# all retrievers ready

# %% [markdown]
# ### ablation experiments
#
# | Exp | Chunking    | Retrieval
# |-----|-------------|-----------
# | A1  | structural  |bm25
# | A2  | structural  | dense
# | A3  | structural  |rrf
# | B1  | semantic    | bm25
# | B2  | semantic    | dense
# | B3  | semantic    | rrf

# %%
all_summaries = []
all_details = {}

for cm in CHUNK_MODES:
    for rm in RETRIEVAL_MODES:
        label = f'{cm}+{rm}'
        print(f'EXPERIMENT: {label}')
        summary, details = run_evaluation(
            qa_path=QA_PATH,
            retriever=retrievers[cm],
            chunk_mode=cm,
            retrieval_method=rm,
            top_k=TOP_K,
        )
        summary['label'] = label
        all_summaries.append(summary)
        all_details[label] = details

print('experiments done')
# Out:
# EXPERIMENT: structural+bm25
#   Q1/20: What is the purpose of the ICC Code of Conduct?…
#     EM=0  F1=0.265  grounding=100%  time=2.51s
#   Q2/20: What does Article 2.3 of the Code of Conduct cover?…
#     EM=0  F1=0.051  grounding=0%  time=0.96s
#   Q3/20: What are the offence levels defined in the Code of Cond…
#     EM=0  F1=0.712  grounding=100%  time=1.66s
#   Q4/20: What does Article 2.5 prohibit regarding a dismissed ba…
#     EM=0  F1=0.474  grounding=100%  time=2.75s
#   Q5/20: What is the sanction for changing the condition of the …
#     EM=0  F1=0.143  grounding=0%  time=1.05s
#   Q6/20: Who can report an alleged offence under the Code of Con…
#     EM=0  F1=0.250  grounding=100%  time=2.30s
#   Q7/20: What does Article 2.12 cover regarding physical contact…
#     EM=0  F1=0.312  grounding=100%  time=2.69s
#   Q8/20: Are social media posts considered public under the Code…
#     EM=0  F1=0.600  grounding=100%  time=1.84s
#   Q9/20: What is the reporting deadline for Level 1 and 2 on-fie…
#     EM=0  F1=0.053  grounding=0%  time=0.77s
#   Q10/20: What language must hearings before the Match Referee be…
#     EM=0  F1=0.643  grounding=100%  time=1.74s
#   Q11/20: What does Article 2.9 cover regarding throwing objects?…
#     EM=0  F1=0.040  grounding=0%  time=0.68s
#   Q12/20: What does Article 2.17 say about threats of assault?…
#     EM=0  F1=0.468  grounding=100%  time=2.78s
#   Q13/20: What is the definition of the Spirit of Cricket accordi…
#     EM=0  F1=0.590  grounding=100%  time=3.04s
#   Q14/20: What options does a Player have after receiving a Notic…
#     EM=0  F1=0.048  grounding=0%  time=0.69s
#   Q15/20: How long does the Match Referee have to issue a written…
#     EM=0  F1=0.556  grounding=100%  time=1.95s
#   Q16/20: What types of unfair play does Article 2.10 cover?…
#     EM=0  F1=0.460  grounding=100%  time=2.90s
#   Q17/20: Where is the ICC headquartered according to the Code of…
#     EM=0  F1=0.190  grounding=0%  time=0.59s
#   Q18/20: When did this Code of Conduct become effective?…
#     EM=0  F1=0.857  grounding=100%  time=0.98s
#   Q19/20: What is Article 2.21 about?…
#     EM=0  F1=0.406  grounding=100%  time=4.12s
#   Q20/20: Who is held responsible for offences under Article 2.11…
#     EM=0  F1=0.933  grounding=100%  time=1.47s
#
#   --- structural + bm25 ---
#   EM:        0.000
#   F1:        0.403
#   Grounding: 70.0%
#   p95 lat:   3.10s
# EXPERIMENT: structural+dense
#   Q1/20: What is the purpose of the ICC Code of Conduct?…
#     EM=0  F1=0.707  grounding=100%  time=1.92s
#   Q2/20: What does Article 2.3 of the Code of Conduct cover?…
#     EM=0  F1=0.051  grounding=0%  time=1.04s
#   Q3/20: What are the offence levels defined in the Code of Cond…
#     EM=0  F1=0.417  grounding=100%  time=1.82s
#   Q4/20: What does Article 2.5 prohibit regarding a dismissed ba…
#     EM=0  F1=0.475  grounding=100%  time=2.80s
#   Q5/20: What is the sanction for changing the condition of the …
#     EM=0  F1=0.143  grounding=0%  time=0.93s
#   Q6/20: Who can report an alleged offence under the Code of Con…
#     EM=0  F1=0.300  grounding=100%  time=1.86s
#   Q7/20: What does Article 2.12 cover regarding physical contact…
#     EM=0  F1=0.000  grounding=0%  time=1.58s
#   Q8/20: Are social media posts considered public under the Code…
#     EM=0  F1=0.600  grounding=100%  time=1.95s
#   Q9/20: What is the reporting deadline for Level 1 and 2 on-fie…
#     EM=0  F1=0.800  grounding=100%  time=3.06s
#   Q10/20: What language must hearings before the Match Referee be…
#     EM=0  F1=0.452  grounding=100%  time=1.52s
#   Q11/20: What does Article 2.9 cover regarding throwing objects?…
#     EM=0  F1=0.040  grounding=0%  time=0.93s
#   Q12/20: What does Article 2.17 say about threats of assault?…
#     EM=0  F1=0.481  grounding=100%  time=2.66s
#   Q13/20: What is the definition of the Spirit of Cricket accordi…
#     EM=0  F1=0.571  grounding=100%  time=2.40s
#   Q14/20: What options does a Player have after receiving a Notic…
#     EM=0  F1=0.048  grounding=0%  time=0.92s
#   Q15/20: How long does the Match Referee have to issue a written…
#     EM=0  F1=0.410  grounding=100%  time=2.91s
#   Q16/20: What types of unfair play does Article 2.10 cover?…
#     EM=0  F1=0.043  grounding=0%  time=1.05s
#   Q17/20: Where is the ICC headquartered according to the Code of…
#     EM=0  F1=0.190  grounding=0%  time=1.11s
#   Q18/20: When did this Code of Conduct become effective?…
#     EM=0  F1=0.857  grounding=100%  time=1.44s
#   Q19/20: What is Article 2.21 about?…
#     EM=0  F1=0.057  grounding=0%  time=1.12s
#   Q20/20: Who is held responsible for offences under Article 2.11…
#     EM=0  F1=0.316  grounding=100%  time=1.82s
#
#   --- structural + dense ---
#   EM:        0.000
#   F1:        0.348
#   Grounding: 60.0%
#   p95 lat:   2.92s
# EXPERIMENT: structural+rrf
#   Q1/20: What is the purpose of the ICC Code of Conduct?…
#     EM=0  F1=0.682  grounding=100%  time=2.60s
#   Q2/20: What does Article 2.3 of the Code of Conduct cover?…
#     EM=0  F1=0.051  grounding=0%  time=1.00s
#   Q3/20: What are the offence levels defined in the Code of Cond…
#     EM=0  F1=0.712  grounding=100%  time=2.44s
#   Q4/20: What does Article 2.5 prohibit regarding a dismissed ba…
#     EM=0  F1=0.468  grounding=100%  time=2.16s
#   Q5/20: What is the sanction for changing the condition of the …
#     EM=0  F1=0.143  grounding=0%  time=0.98s
#   Q6/20: Who can report an alleged offence under the Code of Con…
#     EM=0  F1=0.250  grounding=100%  time=1.70s
#   Q7/20: What does Article 2.12 cover regarding physical contact…
#     EM=0  F1=0.000  grounding=0%  time=0.93s
#   Q8/20: Are social media posts considered public under the Code…
#     EM=0  F1=0.600  grounding=100%  time=2.16s
#   Q9/20: What is the reporting deadline for Level 1 and 2 on-fie…
#     EM=0  F1=0.800  grounding=100%  time=1.73s
#   Q10/20: What language must hearings before the Match Referee be…
#     EM=0  F1=0.596  grounding=100%  time=1.70s
#   Q11/20: What does Article 2.9 cover regarding throwing objects?…
#     EM=0  F1=0.040  grounding=0%  time=0.81s
#   Q12/20: What does Article 2.17 say about threats of assault?…
#     EM=0  F1=0.507  grounding=100%  time=3.24s
#   Q13/20: What is the definition of the Spirit of Cricket accordi…
#     EM=0  F1=0.590  grounding=100%  time=3.34s
#   Q14/20: What options does a Player have after receiving a Notic…
#     EM=0  F1=0.151  grounding=100%  time=1.87s
#   Q15/20: How long does the Match Referee have to issue a written…
#     EM=0  F1=0.556  grounding=100%  time=2.37s
#   Q16/20: What types of unfair play does Article 2.10 cover?…
#     EM=0  F1=0.515  grounding=100%  time=1.81s
#   Q17/20: Where is the ICC headquartered according to the Code of…
#     EM=0  F1=0.190  grounding=0%  time=0.98s
#   Q18/20: When did this Code of Conduct become effective?…
#     EM=0  F1=0.857  grounding=100%  time=1.54s
#   Q19/20: What is Article 2.21 about?…
#     EM=0  F1=0.464  grounding=100%  time=4.10s
#   Q20/20: Who is held responsible for offences under Article 2.11…
#     EM=0  F1=0.889  grounding=100%  time=1.79s
#
#   --- structural + rrf ---
#   EM:        0.000
#   F1:        0.453
#   Grounding: 75.0%
#   p95 lat:   3.38s
# EXPERIMENT: semantic+bm25
#   Q1/20: What is the purpose of the ICC Code of Conduct?…
#     EM=0  F1=0.526  grounding=0%  time=2.35s
#   Q2/20: What does Article 2.3 of the Code of Conduct cover?…
#     EM=0  F1=0.051  grounding=0%  time=0.81s
#   Q3/20: What are the offence levels defined in the Code of Cond…
#     EM=0  F1=0.862  grounding=100%  time=1.53s
#   Q4/20: What does Article 2.5 prohibit regarding a dismissed ba…
#     EM=0  F1=0.557  grounding=100%  time=2.36s
#   Q5/20: What is the sanction for changing the condition of the …
#     EM=0  F1=0.143  grounding=0%  time=0.85s
#   Q6/20: Who can report an alleged offence under the Code of Con…
#     EM=0  F1=0.457  grounding=100%  time=4.40s
#   Q7/20: What does Article 2.12 cover regarding physical contact…
#     EM=0  F1=0.481  grounding=100%  time=3.12s
#   Q8/20: Are social media posts considered public under the Code…
#     EM=0  F1=0.414  grounding=100%  time=2.82s
#   Q9/20: What is the reporting deadline for Level 1 and 2 on-fie…
#     EM=0  F1=0.524  grounding=0%  time=3.10s
#   Q10/20: What language must hearings before the Match Referee be…
#     EM=0  F1=0.744  grounding=100%  time=1.42s
#   Q11/20: What does Article 2.9 cover regarding throwing objects?…
#     EM=0  F1=0.483  grounding=0%  time=4.29s
#   Q12/20: What does Article 2.17 say about threats of assault?…
#     EM=0  F1=0.570  grounding=100%  time=3.53s
#   Q13/20: What is the definition of the Spirit of Cricket accordi…
#     EM=0  F1=0.632  grounding=100%  time=4.72s
#   Q14/20: What options does a Player have after receiving a Notic…
#     EM=0  F1=0.467  grounding=100%  time=3.22s
#   Q15/20: How long does the Match Referee have to issue a written…
#     EM=0  F1=0.536  grounding=100%  time=1.54s
#   Q16/20: What types of unfair play does Article 2.10 cover?…
#     EM=0  F1=0.460  grounding=100%  time=8.51s
#   Q17/20: Where is the ICC headquartered according to the Code of…
#     EM=0  F1=0.190  grounding=0%  time=0.72s
#   Q18/20: When did this Code of Conduct become effective?…
#     EM=0  F1=0.857  grounding=100%  time=1.16s
#   Q19/20: What is Article 2.21 about?…
#     EM=0  F1=0.531  grounding=100%  time=3.23s
#   Q20/20: Who is held responsible for offences under Article 2.11…
#     EM=0  F1=0.885  grounding=100%  time=2.03s
#
#   --- semantic + bm25 ---
#   EM:        0.000
#   F1:        0.518
#   Grounding: 70.0%
#   p95 lat:   4.91s
# EXPERIMENT: semantic+dense
#   Q1/20: What is the purpose of the ICC Code of Conduct?…
#     EM=0  F1=0.580  grounding=100%  time=2.83s
#   Q2/20: What does Article 2.3 of the Code of Conduct cover?…
#     EM=0  F1=0.051  grounding=0%  time=1.05s
#   Q3/20: What are the offence levels defined in the Code of Cond…
#     EM=0  F1=0.453  grounding=100%  time=3.87s
#   Q4/20: What does Article 2.5 prohibit regarding a dismissed ba…
#     EM=0  F1=0.482  grounding=100%  time=3.63s
#   Q5/20: What is the sanction for changing the condition of the …
#     EM=0  F1=0.143  grounding=0%  time=1.07s
#   Q6/20: Who can report an alleged offence under the Code of Con…
#     EM=0  F1=0.416  grounding=100%  time=5.09s
#   Q7/20: What does Article 2.12 cover regarding physical contact…
#     EM=0  F1=0.481  grounding=100%  time=3.30s
#   Q8/20: Are social media posts considered public under the Code…
#     EM=0  F1=0.532  grounding=100%  time=2.34s
#   Q9/20: What is the reporting deadline for Level 1 and 2 on-fie…
#     EM=0  F1=0.800  grounding=100%  time=2.68s
#   Q10/20: What language must hearings before the Match Referee be…
#     EM=0  F1=0.632  grounding=100%  time=2.84s
#   Q11/20: What does Article 2.9 cover regarding throwing objects?…
#     EM=0  F1=0.471  grounding=100%  time=4.23s
#   Q12/20: What does Article 2.17 say about threats of assault?…
#     EM=0  F1=0.589  grounding=100%  time=4.21s
#   Q13/20: What is the definition of the Spirit of Cricket accordi…
#     EM=0  F1=0.537  grounding=100%  time=5.90s
#   Q14/20: What options does a Player have after receiving a Notic…
#     EM=0  F1=0.458  grounding=100%  time=3.94s
#   Q15/20: How long does the Match Referee have to issue a written…
#     EM=0  F1=0.536  grounding=100%  time=2.25s
#   Q16/20: What types of unfair play does Article 2.10 cover?…
#     EM=0  F1=0.460  grounding=100%  time=7.49s
#   Q17/20: Where is the ICC headquartered according to the Code of…
#     EM=0  F1=0.190  grounding=0%  time=0.93s
#   Q18/20: When did this Code of Conduct become effective?…
#     EM=0  F1=0.857  grounding=100%  time=1.56s
#   Q19/20: What is Article 2.21 about?…
#     EM=0  F1=0.057  grounding=0%  time=1.09s
#   Q20/20: Who is held responsible for offences under Article 2.11…
#     EM=0  F1=0.351  grounding=100%  time=1.60s
#
#   --- semantic + dense ---
#   EM:        0.000
#   F1:        0.454
#   Grounding: 80.0%
#   p95 lat:   5.98s
# EXPERIMENT: semantic+rrf
#   Q1/20: What is the purpose of the ICC Code of Conduct?…
#     EM=0  F1=0.699  grounding=100%  time=2.42s
#   Q2/20: What does Article 2.3 of the Code of Conduct cover?…
#     EM=0  F1=0.051  grounding=0%  time=0.99s
#   Q3/20: What are the offence levels defined in the Code of Cond…
#     EM=0  F1=0.568  grounding=100%  time=3.43s
#   Q4/20: What does Article 2.5 prohibit regarding a dismissed ba…
#     EM=0  F1=0.545  grounding=100%  time=2.84s
#   Q5/20: What is the sanction for changing the condition of the …
#     EM=0  F1=0.143  grounding=0%  time=1.03s
#   Q6/20: Who can report an alleged offence under the Code of Con…
#     EM=0  F1=0.394  grounding=100%  time=4.40s
#   Q7/20: What does Article 2.12 cover regarding physical contact…
#     EM=0  F1=0.484  grounding=100%  time=3.36s
#   Q8/20: Are social media posts considered public under the Code…
#     EM=0  F1=0.535  grounding=100%  time=2.06s
#   Q9/20: What is the reporting deadline for Level 1 and 2 on-fie…
#     EM=0  F1=0.524  grounding=100%  time=3.31s
#   Q10/20: What language must hearings before the Match Referee be…
#     EM=0  F1=0.744  grounding=100%  time=1.55s
#   Q11/20: What does Article 2.9 cover regarding throwing objects?…
#     EM=0  F1=0.464  grounding=100%  time=8.57s
#   Q12/20: What does Article 2.17 say about threats of assault?…
#     EM=0  F1=0.570  grounding=100%  time=3.75s
#   Q13/20: What is the definition of the Spirit of Cricket accordi…
#     EM=0  F1=0.519  grounding=100%  time=5.45s
#   Q14/20: What options does a Player have after receiving a Notic…
#     EM=0  F1=0.469  grounding=100%  time=2.76s
#   Q15/20: How long does the Match Referee have to issue a written…
#     EM=0  F1=0.718  grounding=100%  time=1.26s
#   Q16/20: What types of unfair play does Article 2.10 cover?…
#     EM=0  F1=0.460  grounding=100%  time=8.50s
#   Q17/20: Where is the ICC headquartered according to the Code of…
#     EM=0  F1=0.190  grounding=0%  time=0.86s
#   Q18/20: When did this Code of Conduct become effective?…
#     EM=0  F1=0.857  grounding=100%  time=1.44s
#   Q19/20: What is Article 2.21 about?…
#     EM=0  F1=0.444  grounding=100%  time=3.49s
#   Q20/20: Who is held responsible for offences under Article 2.11…
#     EM=0  F1=0.889  grounding=0%  time=1.91s
#
#   --- semantic + rrf ---
#   EM:        0.000
#   F1:        0.513
#   Grounding: 80.0%
#   p95 lat:   8.51s
# experiments done

# %% [markdown]
# ## 5 · Results comparison table

# %%
header = f'{"Experiment":<25} {"EM":>6} {"F1":>6} {"Ground%":>8} {"p95(s)":>7}'
print(header)
print('-' * len(header))

for s in all_summaries:
    print(f'{s["label"]:<25} {s["avg_em"]:>6.3f} {s["avg_f1"]:>6.3f} '
          f'{s["avg_grounding"]:>7.1f}% {s["p95_latency"]:>7.2f}')
# Out:
# Experiment                    EM     F1  Ground%  p95(s)
# --------------------------------------------------------
# structural+bm25            0.000  0.403    70.0%    3.10
# structural+dense           0.000  0.348    60.0%    2.92
# structural+rrf             0.000  0.453    75.0%    3.38
# semantic+bm25              0.000  0.518    70.0%    4.91
# semantic+dense             0.000  0.454    80.0%    5.98
# semantic+rrf               0.000  0.513    80.0%    8.51

# %%
def get_summary(label):
    for s in all_summaries:
        if s['label'] == label:
            return s
    return None

print('Chunking ablation  (RRF held constant)')
for lbl in ['structural+rrf', 'semantic+rrf']:
    s = get_summary(lbl)
    if s:
        print(f'  {lbl:<25}  F1={s["avg_f1"]:.3f}  Grounding={s["avg_grounding"]:.1f}%')

print()
print('Retrieval ablation  (structural chunks held constant)')
for lbl in ['structural+bm25', 'structural+dense', 'structural+rrf']:
    s = get_summary(lbl)
    if s:
        print(f'  {lbl:<25}  F1={s["avg_f1"]:.3f}  Grounding={s["avg_grounding"]:.1f}%')

print()
print('Fusion value')
a1, a2, a3 = get_summary('structural+bm25'), get_summary('structural+dense'), get_summary('structural+rrf')
if a1 and a2 and a3:
    best_single = max(a1['avg_f1'], a2['avg_f1'])
    print(f'  best single retriever F1 = {best_single:.3f}')
    print(f'  RRF fusion F1            = {a3["avg_f1"]:.3f}')
    print(f'  delta                    = {a3["avg_f1"] - best_single:+.3f}')
# Out:
# Chunking ablation  (RRF held constant)
#   structural+rrf             F1=0.453  Grounding=75.0%
#   semantic+rrf               F1=0.513  Grounding=80.0%
#
# Retrieval ablation  (structural chunks held constant)
#   structural+bm25            F1=0.403  Grounding=70.0%
#   structural+dense           F1=0.348  Grounding=60.0%
#   structural+rrf             F1=0.453  Grounding=75.0%
#
# Fusion value
#   best single retriever F1 = 0.403
#   RRF fusion F1            = 0.453
#   delta                    = +0.051

# %% [markdown]
# ### Latency
#
# Measure p50, p95, p99 latency
#
# **Acceptance target:** p95 ≤ 2.5 s at top-k=4 for approx 512-token answers.

# %%
print(f'{"Experiment":<25} {"p50(s)":>7} {"p95(s)":>7} {"p99(s)":>7} {"mean(s)":>7}')
for label, details in all_details.items():
    lats = [d['latency'] for d in details]
    p50 = np.percentile(lats, 50)
    p95 = np.percentile(lats, 95)
    p99 = np.percentile(lats, 99)
    mean = np.mean(lats)
    print(f'{label:<25} {p50:>7.2f} {p95:>7.2f} {p99:>7.2f} {mean:>7.2f}')
# Out:
# Experiment                 p50(s)  p95(s)  p99(s) mean(s)
# structural+bm25              1.79    3.10    3.92    1.87
# structural+dense             1.70    2.92    3.03    1.74
# structural+rrf               1.80    3.38    3.96    1.96
# semantic+bm25                2.59    4.91    7.79    2.79
# semantic+dense               2.83    5.98    7.19    3.09
# semantic+rrf                 2.80    8.51    8.56    3.17
